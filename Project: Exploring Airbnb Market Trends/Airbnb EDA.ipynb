# %% [markdown]
# ![NYC Skyline](nyc.jpg)
#
# Welcome to New York City, one of the most-visited cities in the world. There are many Airbnb listings in New York City to meet the high demand for temporary lodging for travelers, which can be anywhere between a few nights to many months. In this project, we will take a closer look at the New York Airbnb market by combining data from multiple file types like `.csv`, `.tsv`, and `.xlsx`.
#
# Recall that **CSV**, **TSV**, and **Excel** files are three common formats for storing data.
# Three files containing data on 2019 Airbnb listings are available to you:
#
# **data/airbnb_price.csv**
# This is a CSV file containing data on Airbnb listing prices and locations.
# - **`listing_id`**: unique identifier of listing
# - **`price`**: nightly listing price in USD
# - **`nbhood_full`**: name of borough and neighborhood where listing is located
#
# **data/airbnb_room_type.xlsx**
# This is an Excel file containing data on Airbnb listing descriptions and room types.
# - **`listing_id`**: unique identifier of listing
# - **`description`**: listing description
# - **`room_type`**: Airbnb has three types of rooms: shared rooms, private rooms, and entire homes/apartments
#
# **data/airbnb_last_review.tsv**
# This is a TSV file containing data on Airbnb host names and review dates.
# - **`listing_id`**: unique identifier of listing
# - **`host_name`**: name of listing host
# - **`last_review`**: date when the listing was last reviewed

# %%
# Import necessary packages
import pandas as pd
import numpy as np

df3 = pd.read_csv("data/airbnb_price.csv", index_col = 0)
df2 = pd.read_excel("data/airbnb_room_type.xlsx", index_col= 0)
df1 = pd.read_csv("data/airbnb_last_review.tsv", sep='\t', index_col = 0)

# %% [markdown]
# # Junção de DataFrames

# %%
temp_df = pd.merge(df1,df2, on = 'listing_id')
new_df = pd.merge(temp_df, df3, on = 'listing_id')

# %%
new_df.head()
# Out:
#               host_name   last_review  ...        price                nbhood_full
# listing_id                             ...
# 2595           Jennifer   May 21 2019  ...  225 dollars         Manhattan, Midtown
# 3831        LisaRoxanne  July 05 2019  ...   89 dollars     Brooklyn, Clinton Hill
# 5099              Chris  June 22 2019  ...  200 dollars     Manhattan, Murray Hill
# 5178           Shunichi  June 24 2019  ...   79 dollars  Manhattan, Hell's Kitchen
# 5238                Ben  June 09 2019  ...  150 dollars       Manhattan, Chinatown
#
# [5 rows x 6 columns]

# %% [markdown]
# # Determinando datas mais recentes

# %% [markdown]
# ## Convertendo dados para o tipo certo

# %%
new_df_copy = new_df
new_df_copy.dtypes
# Out:
# host_name      object
# last_review    object
# description    object
# room_type      object
# price          object
# nbhood_full    object
# dtype: object

# %%
new_df_copy['last_review'] = pd.to_datetime(new_df_copy['last_review'], format = '%B %d %Y')

# %%
new_df_copy.dtypes
# Out:
# host_name              object
# last_review    datetime64[ns]
# description            object
# room_type              object
# price                  object
# nbhood_full            object
# dtype: object

# %% [markdown]
# ## Verificando datas recentes e antigas

# %%
last_review_date = new_df_copy["last_review"].max()
first_review_date = new_df_copy['last_review'].min()

# %%
print(last_review_date)
# Out:
# 2019-07-09 00:00:00

# %%
print(first_review_date)
# Out:
# 2019-01-01 00:00:00

# %% [markdown]
# # Determinando número de anúncios privados

# %%
new_df_copy.head()
# Out:
#               host_name last_review  ...        price                nbhood_full
# listing_id                           ...
# 2595           Jennifer  2019-05-21  ...  225 dollars         Manhattan, Midtown
# 3831        LisaRoxanne  2019-07-05  ...   89 dollars     Brooklyn, Clinton Hill
# 5099              Chris  2019-06-22  ...  200 dollars     Manhattan, Murray Hill
# 5178           Shunichi  2019-06-24  ...   79 dollars  Manhattan, Hell's Kitchen
# 5238                Ben  2019-06-09  ...  150 dollars       Manhattan, Chinatown
#
# [5 rows x 6 columns]

# %%
new_df_copy["room_type"] = new_df_copy["room_type"].str.capitalize()

# %%
nb_room = new_df_copy["room_type"].value_counts()
print(nb_room)
# Out:
# Entire home/apt    13266
# Private room       11356
# Shared room          587
# Name: room_type, dtype: int64

# %%
nb_private_room = nb_room["Private room"]
print(nb_private_room)
# Out:
# 11356

# %% [markdown]
# # Preço Médio da Listagem

# %%
new_df_copy["price"] = new_df_copy["price"].str.replace("dollars", "").str.strip().astype(int)

# %%
new_df_copy.head()
# Out:
#               host_name last_review  ... price                nbhood_full
# listing_id                           ...
# 2595           Jennifer  2019-05-21  ...   225         Manhattan, Midtown
# 3831        LisaRoxanne  2019-07-05  ...    89     Brooklyn, Clinton Hill
# 5099              Chris  2019-06-22  ...   200     Manhattan, Murray Hill
# 5178           Shunichi  2019-06-24  ...    79  Manhattan, Hell's Kitchen
# 5238                Ben  2019-06-09  ...   150       Manhattan, Chinatown
#
# [5 rows x 6 columns]

# %%
new_df_copy.dtypes
# Out:
# host_name              object
# last_review    datetime64[ns]
# description            object
# room_type              object
# price                   int64
# nbhood_full            object
# dtype: object

# %%
avg_price = new_df_copy["price"].mean().round(2)

# %%
print(avg_price)
# Out:
# 141.78

# %% [markdown]
# # Criação de um dataframe próprio

# %%
review_dates = pd.DataFrame({
    "first_reviewed": [first_review_date],
    "last_reviewed": [last_review_date],
    "nb_private_rooms": [nb_private_room],
    "avg_price": [avg_price]
}, index=[0])

# %%
review_dates.head()
# Out:
#   first_reviewed last_reviewed  nb_private_rooms  avg_price
# 0     2019-01-01    2019-07-09             11356     141.78
